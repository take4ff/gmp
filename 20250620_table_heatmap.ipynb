# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import matplotlib.colors as mcolors
from matplotlib import cm
import seaborn as sns
import cv2

from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm
import glob
import re

# %%
def count_numeric_subfolders(folder_path):
    if not os.path.exists(folder_path):
        raise FileNotFoundError(f"エラー: 指定されたパスが見つかりません: {folder_path}")
    if not os.path.isdir(folder_path):
        raise NotADirectoryError(f"エラー: 指定されたパスはフォルダではありません: {folder_path}")
    numeric_folder_count = 0
    for item in os.listdir(folder_path):
        item_path = os.path.join(folder_path, item)
        if os.path.isdir(item_path) and item.isdigit():
            numeric_folder_count += 1
    return numeric_folder_count

# %%
def import_mutation_paths(base_dir, strain):
    # ホームディレクトリを展開
    base_dir = os.path.expanduser(base_dir)
    strain_dir = os.path.join(base_dir, strain)

    # strain直下のファイルパスを確認
    file_paths = []
    file_path = os.path.join(strain_dir, f"mutation_paths_{strain}.tsv")
    if os.path.exists(file_path):
        file_paths.append(file_path)
    
    # strain/numサブディレクトリを探索
    else:
        if os.path.exists(strain_dir) and os.path.isdir(strain_dir):
            num_dirs = [d for d in os.listdir(strain_dir) if d.isdigit()]
            num_dirs.sort(key=int)  # 数字順にソート

            for num in num_dirs:
                file_path = os.path.join(strain_dir, num, f"mutation_paths_{strain}.tsv")
                if os.path.exists(file_path):
                    file_paths.append(file_path)

    if not file_paths:
        raise FileNotFoundError(f"mutation_paths_{strain}.tsvが{strain_dir}内に見つかりませんでした。")

    return file_paths

# %%
#変異パターンに対応する表中のセルのインクリメント（position step指定可能）
def count_mutation(df,mutation,step):

    bef = mutation[0]
    aft = mutation[-1]
    pos = int(int(mutation[1:-1]) /step + 0.5)
    pattern = f"{bef}->{aft}"

    df.loc[pos-1, pattern] += 1

# 変異パターンの表を作成
def mutation_table(paths,step=1):
    columns = ["position","A->T","A->G","A->C","T->A","T->G","T->C","G->A","G->T","G->C","C->A","C->T","C->G"]
    df = pd.DataFrame(np.zeros((int(30000/step),len(columns)),dtype=int), columns=columns)
    df["position"] = range(1, 30001, step)

    for path in paths:
        for mutations in path:
            for mutation in mutations.split(','):
                count_mutation(df, mutation,step)
    df_all = pd.DataFrame(np.zeros((int(30000/step), 2), dtype=int), columns=["position","all"])
    df_all["position"] = range(1, 30001, step)
    df_all["all"] = df.iloc[:, 1:].sum(axis=1)
    return df,df_all

# タイムステップごとの変異パターンの表を作成（position step指定可能）
def mutation_table_by_timestep(paths,time_step_max, step=1):
    df_timestep = []
    for i in range(time_step_max):
        columns = ["position","A->T","A->G","A->C","T->A","T->G","T->C","G->A","G->T","G->C","C->A","C->T","C->G"]
        df = pd.DataFrame(np.zeros((int(30000/step),len(columns)),dtype=int), columns=columns)
        df["position"] = range(1, 30001, step)

        for path in paths:
            if i >= len(path):
                continue
            for mutation in path[i].split(','):
                count_mutation(df, mutation, step)
        df_timestep.append(df)

    return df_timestep

# %%
# DataFrameをCSVファイルに保存
def save_df(df, output_dir = 'tables', output_file_name = 'mutation_table.csv'):

    os.makedirs(output_dir, exist_ok=True)

    file_path = os.path.join(output_dir, output_file_name)
    df.to_csv(file_path, index=False)
    print(f"Saved: {file_path}")

# タイムステップごとのDataFrameをCSVファイルに保存
def save_timestep_df(timestep_dataframes, output_dir = 'timestep_tables'):

    os.makedirs(output_dir, exist_ok=True)

    for i, df in enumerate(timestep_dataframes):
        file_path = os.path.join(output_dir, f"timestep_{i + 1}.csv")
        df.to_csv(file_path, index=False)
        #print(f"Saved: {file_path}")

# タイムステップごとのヒートマップを作成・保存
def save_heatmaps(df_timestep, step, output_dir = 'timestep_heatmaps'):
    viridis = cm.get_cmap('viridis', 256)
    newcolors = viridis(np.linspace(0, 1, 256))
    newcolors[0, :] = np.array([1, 1, 1, 1])  # 0番目を白に
    white_viridis = mcolors.ListedColormap(newcolors)

    os.makedirs(output_dir, exist_ok=True)

    columns = ["position","A->T","A->G","A->C","T->A","T->G","T->C","G->A","G->T","G->C","C->A","C->T","C->G"]
    x_labels = columns[1:]  # positionを除外

    for i, df in enumerate(df_timestep):
        data = df.iloc[:, 1:]
        norm_data = (data - data.min().min()) / (data.max().max() - data.min().min())
        plt.figure(figsize=(10, 6))
        plt.imshow(norm_data, aspect='auto', cmap=white_viridis, interpolation='nearest', vmin=0, vmax=1)
        plt.colorbar(label='Normalized Value')
        plt.title(f'Timestep {i+1}')
        plt.xlabel('Mutation Type')
        plt.ylabel(f'position')
        plt.xticks(ticks=np.arange(len(x_labels)), labels=x_labels, rotation=45, ha='right')
        plt.yticks(ticks=np.arange(0, len(df) + 1, step // 2), labels=(np.arange(0, len(df) + 1, step // 2) * step).astype(int))
        plt.tight_layout()
        plt.savefig(f'{output_dir}/mutation_heatmap_timestep_{i+1}.png')
        plt.close()
    print('ヒートマップを保存しました。')

def save_heatmap(df, step, output_dir = 'timestep_heatmaps'):
    viridis = cm.get_cmap('viridis', 256)
    newcolors = viridis(np.linspace(0, 1, 256))
    newcolors[0, :] = np.array([1, 1, 1, 1])  # 0番目を白に
    white_viridis = mcolors.ListedColormap(newcolors)

    os.makedirs(output_dir, exist_ok=True)

    columns = ["position","A->T","A->G","A->C","T->A","T->G","T->C","G->A","G->T","G->C","C->A","C->T","C->G"]
    x_labels = columns[1:]  # positionを除外

    data = df.iloc[:, 1:]
    norm_data = (data - data.min().min()) / (data.max().max() - data.min().min())
    plt.figure(figsize=(10, 6))
    plt.imshow(norm_data, aspect='auto', cmap=white_viridis, interpolation='nearest', vmin=0, vmax=1)
    plt.colorbar(label='Normalized Value')
    plt.xlabel('Mutation Type')
    plt.ylabel(f'position')
    plt.xticks(ticks=np.arange(len(x_labels)), labels=x_labels, rotation=45, ha='right')
    plt.yticks(ticks=np.arange(0, len(df) + 1, step // 2), labels=(np.arange(0, len(df) + 1, step // 2) * step).astype(int))
    plt.tight_layout()
    plt.savefig(f'{output_dir}/mutation_heatmap.png')
    plt.close()
    print('ヒートマップを保存しました。')

# タイムステップごとのヒートマップ画像から動画を作成
def create_video_from_heatmaps(image_folder, output_video_path="timestep_heatmaps/mutation_heatmaps_video.mp4", fps=2):
    # Get list of image files sorted by timestep
    images = [img for img in os.listdir(image_folder) if img.endswith(".png") and "heatmap_timestep" in img]
    images.sort(key=lambda x: int(x.split('_')[-1].split('.')[0]))  # Sort by timestep

    # Read the first image to get dimensions
    if not images:
        raise ValueError("No valid heatmap images found in the specified folder.")

    first_image_path = os.path.join(image_folder, images[0])
    frame = cv2.imread(first_image_path)
    height, width, layers = frame.shape

    # Initialize video writer
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    video = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    # Add images to the video
    for image in images:
        image_path = os.path.join(image_folder, image)
        frame = cv2.imread(image_path)
        video.write(frame)

    video.release()

# %%
#mutation-pathsを転置して重複を除去
def transposition_and_set(paths):
    timestep_mutation = {}

    for path in paths:
        for timestep, sample in enumerate(path):
            if timestep not in timestep_mutation:
                timestep_mutation[timestep] = set()
            timestep_mutation[timestep].add(sample)

    return timestep_mutation

#タイムステップごとのリストを1次リストに変換
def to1Dlist(timestep_data):

    mutation_list = []
    
    for timestep, mutations in timestep_data.items():
        #print(mutations)
        for mutation in mutations:
            #rint(mutation)
            mutation_list.append(mutation)
    
    return mutation_list

# 重複を除去した1次リストから変異パターンの表を作成（position step指定可能）
def mutation_table_form_1Dlist(path,step=1):
    columns = ["position","A->T","A->G","A->C","T->A","T->G","T->C","G->A","G->T","G->C","C->A","C->T","C->G"]
    df = pd.DataFrame(np.zeros((int(30000/step),len(columns)),dtype=int), columns=columns)
    df["position"] = range(1, 30001, step)

    for mutations in path:
        for mutation in mutations.split(','):
            count_mutation(df, mutation,step)
    df_all = pd.DataFrame(np.zeros((int(30000/step), 2), dtype=int), columns=["position","all"])
    df_all["position"] = range(1, 30001, step)
    df_all["all"] = df.iloc[:, 1:].sum(axis=1)
    return df,df_all

# %%
def tables_summary(strains,timestep_max_list,output_dir, tables_dir):
    output_dir_ts_sum = os.path.join(output_dir, "timestep_tables")
    #timestep_tables_summaryの作成
    ts_max = max(timestep_max_list)
    os.makedirs(output_dir_ts_sum+"/default", exist_ok=True)
    columns = ["position","A->T","A->G","A->C","T->A","T->G","T->C","G->A","G->T","G->C","C->A","C->T","C->G"]
    df_summary = pd.DataFrame(np.zeros((int(30000),len(columns)),dtype=int), columns=columns)
    df_summary["position"] = range(1, 30001)
    for ts in range(1,ts_max+1):
        df_summary_ts = pd.DataFrame(np.zeros((int(30000),len(columns)),dtype=int), columns=columns)
        df_summary_ts["position"] = range(1, 30001)
        for strain in strains:
            file_path = os.path.join(tables_dir, strain, f"timestep_{ts}.csv")
            if not os.path.exists(os.path.join(file_path)):
                continue
            #print(f"[INFO] {strain}のtimestep_{ts}.csvを読み込み中")
            df_strain = pd.read_csv(file_path)
            for col in df_strain.columns[1:]:
                df_summary_ts[col] += df_strain[col]
        save_df(df_summary_ts, output_dir_ts_sum+"/default", f"timestep_{ts}.csv")
        
        for col in df_summary_ts.columns[1:]:
            df_summary[col] += df_summary_ts[col]
    save_df(df_summary, output_dir, "tables.csv")

    df_all = pd.DataFrame(np.zeros((int(30000), 2), dtype=int), columns=["position","all"])
    df_all["position"] = range(1, 30001)
    df_all["all"] = df_summary.iloc[:, 1:].sum(axis=1)
    save_df(df_all, output_dir, "tables_sum.csv")

    return df_summary_ts

# %%
def compress_csv_rows(file,step):
    #print(f"Processing file: {file}")
    df = pd.read_csv(file)
    compressed_rows = []
    for i in range(0, len(df), step):
        block = df.iloc[i:i+step]
        if len(block) == 0:
            continue
        row = {}
        row['position'] = block.iloc[0, 0]  # 先頭行のposition
        # 2列目以降を合計
        for col in df.columns[1:]:
            row[col] = block[col].sum()
        compressed_rows.append(row)
    df_compressed = pd.DataFrame(compressed_rows)
    return df_compressed

def compress_csv_rows_folder(input_dir, output_dir, step=100):
    df_compressed_ts = []
    os.makedirs(output_dir, exist_ok=True)

    def natural_key(filename):
        # ファイル名から数字部分を抽出してintで返す
        m = re.search(r'(\d+)', os.path.basename(filename))
        return int(m.group(1)) if m else 0
    
    csv_files = sorted(glob.glob(os.path.join(input_dir, "*.csv")), key=natural_key)
    for file in csv_files:
        df_compressed = compress_csv_rows(file,step)
        out_path = os.path.join(output_dir, os.path.basename(file))
        df_compressed.to_csv(out_path, index=False)
        df_compressed_ts.append(df_compressed)
        print(f"Saved: {out_path}")
    return df_compressed_ts

# %%
strains = ['B.1.1.7','P.1','BA.2','BA.1.1','BA.1','B.1.617.2','B.1.351','B.1.1.529']
#strains = ['P.1','B.1.1.529']
usher_dir = '~/usher_output/'

dir_ver = "0621"
output_dir = os.path.join("table_heatmap", dir_ver)
tables_dir = os.path.join(output_dir, "timestep_tables/strains")

timestep_max_list = []

for strain in strains:
    names = []
    lengths = []
    paths = []
    file_paths = import_mutation_paths(usher_dir,strain)
    for file_path in file_paths:
        print(f"[INFO]import: {file_path}")
        f = open(file_path, 'r',encoding="utf-8_sig")
        datalist = f.readlines()
        f.close()

        data_num = 10 #len(datalist)

        for i in range(1,data_num):
            data = datalist[i].split('\t')
            names.append(data[0])
            lengths.append(int(data[1]))
            paths.append(data[2].rstrip().split('>'))

    print(f"[INFO] {strain}のデータ読み込み完了: {len(paths)} サンプル")
    print(paths[0])

    timestep_max = max(lengths)
    timestep_max_list.append(timestep_max)

    tables_dir_strain = os.path.join(tables_dir, strain)
    df_timestep = mutation_table_by_timestep(paths,timestep_max)
    save_timestep_df(df_timestep, tables_dir_strain)  
df_timestep = tables_summary(strains, timestep_max_list, output_dir, tables_dir)
# Out:
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/0/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/1/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/2/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/3/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/4/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/5/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/6/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/7/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/8/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/9/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/10/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/11/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/12/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/13/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/14/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/15/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/16/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/17/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/18/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/19/mutation_paths_B.1.1.7.tsv
# [INFO] B.1.1.7のデータ読み込み完了: 180 サンプル
# ['C14408T', 'A23403G', 'C241T', 'C3037T', 'G28881A', 'G28882A,G28883C', 'C884T', 'T884C,G28280C,A28281T,T28282A', 'A23063T', 'C15279T', 'A28111G,C28977T', 'T23063A', 'C913T', 'C5986T', 'T6954C,A23063T,C23271A,C23604A,C23709T', 'T24506G,G24914C', 'T16176C', 'C14676T,C27972T', 'C3267T', 'C5388A', 'G28048T', 'A12097G', 'G3259T', 'C7029T', 'T1054C', 'C7749T', 'C203A', 'C21588T', 'C28312T']
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/P.1/mutation_paths_P.1.tsv
# [INFO] P.1のデータ読み込み完了: 9 サンプル
# ['C14408T', 'A23403G', 'C241T', 'C3037T', 'G28881A', 'G28882A,G28883C', 'C23525T', 'G23012A', 'A6613G,G21974T,A22812C,A23063T,G25088T,T26149C,C28512G,A28877T,G28878C', 'C12778T,C13860T,G17259T', 'C3828T,A5648C,G28167A', 'C24642T', 'T733C,A6319G', 'C2749T', 'C22812A', 'G22132T', 'C21614T,C21621A', 'C21638T', 'A22812C', 'C6627T', 'G2664A,C15352T,A21169G', 'C16428T,C20703T,G21786T,C28826T']
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/0/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/1/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/2/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/3/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/4/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/5/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/6/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/7/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/8/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/9/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/10/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/11/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/12/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/13/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/14/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/15/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/16/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/17/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/18/mutation_paths_BA.2.tsv
# [INFO] BA.2のデータ読み込み完了: 171 サンプル
# ['C14408T', 'A23403G', 'C241T', 'C3037T', 'G28881A', 'G28882A,G28883C', 'C23604A', 'T23599G,A28271T,C28311T', 'C10029T,C15240T,G22578A,T22673C,C22674T,T22679C,C22686T,G22992A,C22995A,A23013C,A23040G,A23055G,A23063T,T23075C,C23525T,A24424T,T24469A,C25584T', 'C10449A,C21762T,C21846T,C23854A,G23948T,C24130A,C25000T,A27259C,C27807T', 'A18163G,C26270T,C26577G', 'G26709A', 'T22882G', 'G22813T,A26530G', 'A24130C', 'T13195C', 'C22673T,G22775A', 'C13195T,T15240C,G26530A', 'G4184A,G10447A,C12880T,C15714T', 'T670G,C4321T,C9534T,C17410T,C19955T,A20055G,T21762C,T21846C,A22786C,A29510C', 'C10198T', 'C9866T,T14408C,C26060T,C26858T,G27382C,A27383T', 'C21618T,T27384C', 'C14408T,T22200G', 'A22688G', 'C9344T', 'A9424G', 'C2790T', 'C22792T', 'C4438T']
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/0/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/1/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/2/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/3/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/4/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/5/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/6/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/7/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/8/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/9/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/10/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/11/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/12/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/13/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/14/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/15/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/16/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/17/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/18/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/19/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/20/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/21/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/22/mutation_paths_BA.1.1.tsv
# [INFO] BA.1.1のデータ読み込み完了: 207 サンプル
# ['C14408T', 'A23403G', 'C241T', 'C3037T', 'G28881A', 'G28882A,G28883C', 'C23604A', 'T23599G,A28271T,C28311T', 'C10029T,C15240T,G22578A,T22673C,C22674T,T22679C,C22686T,G22992A,C22995A,A23013C,A23040G,A23055G,A23063T,T23075C,C23525T,A24424T,T24469A,C25584T', 'C10449A,C21762T,C21846T,C23854A,G23948T,C24130A,C25000T,A27259C,C27807T', 'A18163G,C26270T,C26577G', 'G26709A', 'T22882G', 'G22813T,A26530G', 'A24130C', 'G8393A,A11537G,G26530A', 'G23048A', 'G22898A,C23202A,A26530G', 'A2832G,T13195C,A23048G,C24130A,C24503T', 'T5386G', 'G23048A', 'G22599A', 'C2470T', 'C27741T', 'G28079T', 'C25658T']
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/0/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/1/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/2/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/3/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/4/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/5/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/6/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/7/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/8/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/9/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/10/mutation_paths_BA.1.tsv
# [INFO] BA.1のデータ読み込み完了: 99 サンプル
# ['C14408T', 'A23403G', 'C241T', 'C3037T', 'G28881A', 'G28882A,G28883C', 'C23604A', 'T23599G,A28271T,C28311T', 'C10029T,C15240T,G22578A,T22673C,C22674T,T22679C,C22686T,G22992A,C22995A,A23013C,A23040G,A23055G,A23063T,T23075C,C23525T,A24424T,T24469A,C25584T', 'C10449A,C21762T,C21846T,C23854A,G23948T,C24130A,C25000T,A27259C,C27807T', 'A18163G,C26270T,C26577G', 'G26709A', 'T22882G', 'G22813T,A26530G', 'A24130C', 'G8393A,A11537G,G26530A', 'G23048A', 'G22898A,C23202A,A26530G', 'T13195C,C24503T', 'C24130A', 'A2832G', 'A23048G', 'T5386G', 'G23048A', 'G5515T']
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.617.2/0/mutation_paths_B.1.617.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.617.2/1/mutation_paths_B.1.617.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.617.2/2/mutation_paths_B.1.617.2.tsv
# [INFO] B.1.617.2のデータ読み込み完了: 27 サンプル
# ['C14408T', 'A23403G', 'C241T', 'C3037T', 'G29742T', 'T22917G', 'T27638C', 'G28881T', 'C21618G', 'G210T', 'C23604G,G29402T', 'C25469T', 'C22995A,C27752T,A28461G', 'C16466T', 'T26767C', 'G15451A', 'C10029T', 'C19220T', 'G28916T', 'G4181T', 'C27874T', 'C6402T', 'C7124T', 'G9053T', 'C8986T', 'T6402C', 'A11332G', 'A11201G', 'C6402T', 'T6661C', 'C20762T,C27638T,T28820A', 'G29260A', 'C2847T,C24048T,C26571T', 'C21846T']
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.351/mutation_paths_B.1.351.tsv
# [INFO] B.1.351のデータ読み込み完了: 9 サンプル
# ['C14408T', 'A23403G', 'C241T', 'C3037T', 'A10323G', 'A2692T,A21801C,A23063T,C23664T,C25904T', 'T2692A', 'C1059T', 'G5230T,T23063A,G25563T,C26456T', 'G22813T', 'C28887T', 'G174T', 'A23063T', 'G23012A', 'A22206G', 'A28254C', 'C17999T', 'C8043T', 'A18424G']
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.529/mutation_paths_B.1.1.529.tsv
# [INFO] B.1.1.529のデータ読み込み完了: 9 サンプル
# ['C14408T', 'A23403G', 'C241T', 'C3037T', 'G28881A', 'G28882A,G28883C', 'C23604A', 'T23599G', 'A28271T,C28311T', 'C10029T,T24469A', 'G22578A,T22673C,C22674T,T22679C,C22686T,A24424T', 'A23040G,A23055G,A23063T,T23075C', 'G22992A,C22995A,A23013C', 'C15240T,C23525T,C25584T', 'C21762T,C21846T,G23948T', 'C10449A,C23854A,C24130A,C25000T,A27259C,C27807T', 'A18163G,C26270T,C26577G', 'G26709A', 'T22882G', 'G22813T', 'A26530G', 'A24130C', 'G8393A,A11537G', 'A22578G']
# Saved: table_heatmap/0000/timestep_tables/default/timestep_1.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_2.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_3.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_4.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_5.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_6.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_7.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_8.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_9.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_10.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_11.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_12.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_13.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_14.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_15.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_16.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_17.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_18.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_19.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_20.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_21.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_22.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_23.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_24.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_25.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_26.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_27.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_28.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_29.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_30.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_31.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_32.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_33.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_34.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_35.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_36.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_37.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_38.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_39.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_40.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_41.csv
# Saved: table_heatmap/0000/timestep_tables/default/timestep_42.csv
# Saved: table_heatmap/0000/tables.csv
# Saved: table_heatmap/0000/tables_sum.csv

# %%
pos_step = 100
input_dir_pos_step = os.path.join(output_dir, "timestep_tables/default")
output_dir_pos_step = os.path.join(output_dir, "timestep_tables/pos-step" + str(pos_step))
df_timestep_pos_step = compress_csv_rows_folder(input_dir_pos_step, output_dir_pos_step, pos_step)

heatmaps_dir = os.path.join(output_dir, "timestep_heatmaps/pos-step" + str(pos_step))
save_heatmaps(df_timestep_pos_step, pos_step, heatmaps_dir)
create_video_from_heatmaps(heatmaps_dir, heatmaps_dir+"/mutation_heatmaps_video.mp4", fps=1)
# Out:
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_1.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_2.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_3.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_4.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_5.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_6.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_7.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_8.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_9.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_10.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_11.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_12.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_13.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_14.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_15.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_16.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_17.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_18.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_19.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_20.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_21.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_22.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_23.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_24.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_25.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_26.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_27.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_28.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_29.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_30.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_31.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_32.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_33.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_34.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_35.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_36.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_37.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_38.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_39.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_40.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_41.csv
# Saved: table_heatmap/0000/timestep_tables/pos-step100/timestep_42.csv
# /tmp/ipykernel_39425/2356157618.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   viridis = cm.get_cmap('viridis', 256)
# ヒートマップを保存しました。

# %%
# --- データ読み込み・前処理 ---
strains = ['B.1.1.7','P.1','BA.2','BA.1.1','BA.1','B.1.617.2','B.1.351','B.1.1.529']
#strains = ['P.1','B.1.1.529']
usher_dir = '~/usher_output/'
max_co_occur = 5

# 全件データの読み込み
names = []
lengths = []
paths = []
for strain in strains:
    file_paths = import_mutation_paths(usher_dir,strain)
    for file_path in file_paths:
        print(f"[INFO]import: {file_path}")
        f = open(file_path, 'r',encoding="utf-8_sig")
        datalist = f.readlines()
        f.close()

        data_num = 10 #or len(datalist)

        for i in range(1,data_num):
            data = datalist[i].split('\t')
            names.append(data[0])
            lengths.append(int(data[1]))
            paths.append(data[2].rstrip().split('>'))
    
print(f"[INFO] 全件読み込み完了: {len(paths)} サンプル")
# Out:
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/0/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/1/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/2/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/3/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/4/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/5/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/6/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/7/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/8/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/9/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/10/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/11/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/12/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/13/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/14/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/15/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/16/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/17/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/18/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.7/19/mutation_paths_B.1.1.7.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/P.1/mutation_paths_P.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/0/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/1/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/2/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/3/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/4/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/5/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/6/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/7/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/8/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/9/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/10/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/11/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/12/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/13/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/14/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/15/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/16/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/17/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.2/18/mutation_paths_BA.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/0/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/1/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/2/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/3/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/4/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/5/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/6/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/7/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/8/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/9/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/10/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/11/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/12/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/13/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/14/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/15/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/16/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/17/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/18/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/19/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/20/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/21/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1.1/22/mutation_paths_BA.1.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/0/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/1/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/2/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/3/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/4/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/5/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/6/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/7/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/8/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/9/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/BA.1/10/mutation_paths_BA.1.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.617.2/0/mutation_paths_B.1.617.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.617.2/1/mutation_paths_B.1.617.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.617.2/2/mutation_paths_B.1.617.2.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.351/mutation_paths_B.1.351.tsv
# [INFO]import: /mnt/ssd1/home3/aiba/usher_output/B.1.1.529/mutation_paths_B.1.1.529.tsv
# [INFO] 全件読み込み完了: 711 サンプル

# %%
output_dir_set = os.path.join(output_dir, "table_set")
timestep_data = transposition_and_set(paths)
mutation_list = to1Dlist(timestep_data)
df_set,df_set_all = mutation_table([mutation_list])
save_df(df_set, output_dir_set, output_file_name = 'table_set.csv')
save_df(df_set_all, output_dir_set, output_file_name = 'table_set_sum.csv')
# Out:
# Saved: table_heatmap/0000/table_set/table_set.csv
# Saved: table_heatmap/0000/table_set/table_set_sum.csv

# %%
pos_step = 100
df_set_path = os.path.join(output_dir_set, "table_set.csv")
df_set_pos_step = compress_csv_rows(df_set_path,pos_step)

save_df(df_set_pos_step, output_dir_set, output_file_name = 'table_set_pos-step'+str(pos_step)+'.csv')
save_heatmap(df_set_pos_step,pos_step,output_dir_set)
# Out:
# Saved: table_heatmap/0000/table_set/table_set_pos-step100.csv
# ヒートマップを保存しました。
# /tmp/ipykernel_39425/2356157618.py:49: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   viridis = cm.get_cmap('viridis', 256)

# %%
timestep_data
# Out:
# {0: {'C14408T'},
#  1: {'A23403G'},
#  2: {'C241T'},
#  3: {'C3037T'},
#  4: {'A10323G', 'G28881A', 'G29742T'},
#  5: {'A2692T,A21801C,A23063T,C23664T,C25904T', 'G28882A,G28883C', 'T22917G'},
#  6: {'C23525T', 'C23604A', 'C884T', 'T2692A', 'T27638C'},
#  7: {'C1059T',
#   'G23012A',
#   'G28881T',
#   'T23599G',
#   'T23599G,A28271T,C28311T',
#   'T884C,G28280C,A28281T,T28282A'},
#  8: {'A23063T',
#   'A28271T,C28311T',
#   'A6613G,G21974T,A22812C,A23063T,G25088T,T26149C,C28512G,A28877T,G28878C',
#   'C10029T,C15240T,G22578A,T22673C,C22674T,T22679C,C22686T,G22992A,C22995A,A23013C,A23040G,A23055G,A23063T,T23075C,C23525T,A24424T,T24469A,C25584T',
#   'C10029T,G22578A,T22673C,C22674T,T22679C,C22686T,G22992A,C22995A,A23013C,A23040G,A23055G,A23063T,T23075C,C23525T',
#   'C21618G',
#   'G22578A,C22674T,T22679C,C22686T,G22992A,C22995A,A23013C,A23040G,A23055G,A23063T,T23075C,C23525T,A24424T,T24469A',
#   'G5230T,T23063A,G25563T,C26456T'},
#  9: {'C10029T,C15240T,T22673C,C25584T',
#   'C10029T,T24469A',
#   'C10449A,C21762T,C21846T,C23854A,G23948T,C24130A,C25000T,A27259C,C27807T',
#   'C12778T,C13860T,G17259T',
#   'C15240T,A24424T,T24469A,C25584T',
#   'C15279T',
#   'G210T',
#   'G22813T'},
#  10: {'A18163G,C26270T,C26577G',
#   'A28111G,C28977T',
#   'C10449A,C21762T,C21846T,C23854A,G23948T,C24130A,C25000T,A27259C,C27807T',
#   'C23604G,G29402T',
#   'C28887T',
#   'C3828T,A5648C,G28167A',
#   'G22578A,T22673C,C22674T,T22679C,C22686T,A24424T'},
#  11: {'A18163G,C26270T,C26577G',
#   'A23040G,A23055G,A23063T,T23075C',
#   'C24642T',
#   'C25469T',
#   'G174T',
#   'G26709A',
#   'T23063A'},
#  12: {'A23063T',
#   'C22995A,C27752T,A28461G',
#   'C913T',
#   'G22992A,C22995A,A23013C',
#   'G26709A',
#   'T22882G',
#   'T733C,A6319G'},
#  13: {'C15240T,C23525T,C25584T',
#   'C16466T',
#   'C2749T',
#   'C5986T',
#   'G22813T,A26530G',
#   'G23012A',
#   'T22882G'},
#  14: {'A22206G',
#   'A24130C',
#   'C21762T,C21846T,G23948T',
#   'C22812A',
#   'G22813T,A26530G',
#   'T26767C',
#   'T6954C,A23063T,C23271A,C23604A,C23709T'},
#  15: {'A24130C',
#   'A2692T',
#   'A28254C',
#   'A9274G',
#   'C10449A,C23854A,C24130A,C25000T,A27259C,C27807T',
#   'G15451A',
#   'G21641T',
#   'G22132T',
#   'G8393A',
#   'G8393A,A11537G,G26530A',
#   'T13195C',
#   'T24506G,G24914C'},
#  16: {'A11537G,G26530A',
#   'A18163G,C26270T,C26577G',
#   'A2530G',
#   'C10029T',
#   'C11812A',
#   'C17766T',
#   'C17999T',
#   'C21614T',
#   'C21614T,C21621A',
#   'C22673T,G22775A',
#   'C9891T',
#   'C9891T,T11418C',
#   'G23048A',
#   'G8393A,A11537G,G26530A',
#   'T13195C',
#   'T16176C'},
#  17: {'C11514T',
#   'C13195T,T15240C,G26530A',
#   'C14676T,C27972T',
#   'C19220T',
#   'C21191T',
#   'C21638T',
#   'C22673T,G22775A',
#   'C26645T',
#   'C26882T',
#   'C346T,C28603T',
#   'C8043T',
#   'G18090A,G25906T',
#   'G22898A,C23202A,A26530G',
#   'G23048A',
#   'G26709A',
#   'T11418C',
#   'T4213C'},
#  18: {'A18424G',
#   'A22812C',
#   'A2832G,T13195C',
#   'A2832G,T13195C,A23048G,C24130A,C24503T',
#   'A2832G,T13195C,C24130A,C24503T',
#   'C11514T',
#   'C13195T,T15240C,G26530A',
#   'C21618T',
#   'C3267T',
#   'C5184T',
#   'G22898A,C23202A,A26530G',
#   'G28884T',
#   'G28916T',
#   'G4184A,G10447A,C12880T,C15714T',
#   'T13195C',
#   'T13195C,C24130A,C24503T',
#   'T13195C,C24503T',
#   'T201C',
#   'T22882G'},
#  19: {'A23048G',
#   'A2832G',
#   'A2832G,C24503T',
#   'A2832G,T13195C,C24130A,C24503T',
#   'A5584G',
#   'C19955T,A20055G,T21846C',
#   'C19955T,T21762C,T21846C',
#   'C24130A',
#   'C24503T',
#   'C25509T',
#   'C3117T',
#   'C4321T,C10198T,T21762C,T21846C,A22786C',
#   'C4321T,C9534T,C10198T,C17410T,A22786C',
#   'C4321T,C9534T,T21762C,T21846C,A22786C',
#   'C4321T,T21846C',
#   'C5184T',
#   'C5388A',
#   'C6627T',
#   'G22813T',
#   'G25767T',
#   'G4181T',
#   'G4184A,G10447A,C12880T,C15714T',
#   'G713A,C11173T',
#   'T13195C,C24130A',
#   'T21762C',
#   'T5386G',
#   'T670G,C17410T',
#   'T670G,C4321T,C9534T,C10198T,C17410T,C19955T,A20055G,T21762C,T21846C,A22786C,A29510C',
#   'T670G,C4321T,C9534T,C17410T,C19955T,A20055G,T21762C,T21846C,A22786C,A29510C',
#   'T7106C'},
#  20: {'A18945G',
#   'A20055G,T21762C,T21846C',
#   'A23048G',
#   'A26530G',
#   'A2832G',
#   'A2832G,C24503T',
#   'A5584G',
#   'C10198T',
#   'C13019T',
#   'C22498T',
#   'C24130A',
#   'C26858T',
#   'C27874T',
#   'C4321T,C17410T,C19955T,T21846C,A29510C',
#   'C4321T,C19955T,A20055G',
#   'C9866T,T14408C,C26060T,C26858T,G27382C,A27383T',
#   'G23048A',
#   'G2659C,C13197T',
#   'G2664A,C15352T,A21169G',
#   'G28048T',
#   'G6476T',
#   'T5386G',
#   'T670G,C19955T,A20055G,T21762C,T21846C,A29510C',
#   'T670G,C4321T,C9534T,C10198T,C17410T,A20055G,A22786C,A29510C',
#   'T670G,C9534T,C10198T,C17410T,C19955T,A20055G,T21762C,A22786C,A29510C',
#   'T670G,C9534T,C17410T,C19955T,A20055G,A29510C'},
#  21: {'A12097G',
#   'A17615G',
#   'A21993C',
#   'A23048G',
#   'A24130C',
#   'A28095T',
#   'A28877T,G28878C',
#   'C10833T',
#   'C11750T',
#   'C12970T',
#   'C13019T',
#   'C14408T,C21618T,T22200G,A22688G,T27384C',
#   'C14408T,C21618T,T22200G,T27384C',
#   'C16428T,C20703T,G21786T,C28826T',
#   'C18555T',
#   'C21059T',
#   'C2110T',
#   'C21855T',
#   'C22227T',
#   'C23683T',
#   'C2453T',
#   'C25844T',
#   'C26013T,A28792T',
#   'C26060T,C26858T',
#   'C3177T',
#   'C4206T',
#   'C4321T,C9534T,C10198T,C19955T,A22786C,A29510C',
#   'C6402T',
#   'C6636T',
#   'C7029T',
#   'C9534T,C17410T,T21762C,A22786C,A29510C',
#   'C9866T',
#   'C9866T,T14408C',
#   'C9866T,T14408C,C26060T,C26858T,G27382C,A27383T',
#   'C9866T,T14408C,C26060T,G27382C,A27383T',
#   'G10193A,A10195T',
#   'G11507A',
#   'G21770A',
#   'G22599A',
#   'G23048A',
#   'G25690T',
#   'G25954T',
#   'G28739T',
#   'G28916T',
#   'G3638T',
#   'G4255A',
#   'T12388C',
#   'T15096C',
#   'T5386G',
#   'T628C',
#   'T670G,C17410T,C19955T,A20055G,A29510C',
#   'T670G,C9534T,C17410T,T21846C,A22786C,A29510C',
#   'T670G,C9534T,T21762C,A22786C'},
#  22: {'A12162G',
#   'A13269C',
#   'A13756G',
#   'A1643T',
#   'A20055G',
#   'A20418G',
#   'A21766C',
#   'A22688G',
#   'A22995C',
#   'A24385T,C25096T',
#   'A28095T',
#   'A28877T',
#   'A3933C',
#   'A5546G,G16402T,C17465T,C23077T',
#   'A761G',
#   'A8512G',
#   'C10198T',
#   'C11455T',
#   'C13059T',
#   'C13423T',
#   'C14120T',
#   'C14408T,C21618T,T22200G,A22688G,T27384C',
#   'C14408T,C21618T,T22200G,T27384C',
#   'C15654T',
#   'C15763T',
#   'C16391T,A17236G',
#   'C16468T',
#   'C1812T',
#   'C18568T',
#   'C186T',
#   'C1912T',
#   'C19854T',
#   'C19983T,C29108T',
#   'C2110T',
#   'C21595T',
#   'C21618T,T27384C',
#   'C21635A',
#   'C22227T',
#   'C22432T',
#   'C22673T',
#   'C23075T',
#   'C24334T',
#   'C24418T',
#   'C2453T',
#   'C2470T',
#   'C25006T',
#   'C25096T',
#   'C25511T',
#   'C25904T',
#   'C26060T,C26858T,G27382C,A27383T',
#   'C26873T',
#   'C27874T',
#   'C2841T',
#   'C2902T',
#   'C29541T',
#   'C29585T',
#   'C29632T',
#   'C5025T',
#   'C5284T',
#   'C7124T',
#   'C8950T',
#   'C8986T',
#   'C8991T',
#   'C920T',
#   'C9264T',
#   'C9344T',
#   'C9866T,T14408C,C26060T,C26858T,G27382C,A27383T',
#   'C9866T,T14408C,G27382C,A27383T',
#   'G10105T',
#   'G11507A',
#   'G11540A',
#   'G1304A',
#   'G15372A',
#   'G16377T',
#   'G16744A',
#   'G16827A',
#   'G21974C',
#   'G22468T',
#   'G2272T,C29498G',
#   'G23048A',
#   'G23587C',
#   'G25437T',
#   'G25690T',
#   'G26062T',
#   'G28378T',
#   'G28396T',
#   'G28884C',
#   'G29027T',
#   'G29744T',
#   'G3259T',
#   'G4136T',
#   'G5515T',
#   'G5584A',
#   'G8393A,A11537G',
#   'T1041C,T20827C',
#   'T14408C,C26060T,C26858T,G27382C,A27383T',
#   'T15096C',
#   'T21294A,G21295A,G21296A',
#   'T24499C',
#   'T24503C',
#   'T2989C',
#   'T4237A,T8885C',
#   'T5386G',
#   'T6495A',
#   'T670G,C4321T',
#   'T6991C',
#   'T7247C',
#   'T7919C',
#   'T8603C'},
#  23: {'A10323G',
#   'A11246G',
#   'A12250G',
#   'A14940G',
#   'A1588G',
#   'A16417G',
#   'A17406G',
#   'A17615G',
#   'A18585C',
#   'A19079G',
#   'A21006G',
#   'A21194G',
#   'A21766C',
#   'A22578G',
#   'A22688G',
#   'A2276G',
#   'A22992G',
#   'A27617G',
#   'A28095T',
#   'A28254C',
#   'A3058G',
#   'A3872C',
#   'A4040C,C25614T',
#   'A4964G',
#   'A9134G',
#   'A9424G',
#   'C10125T',
#   'C10198T',
#   'C103T',
#   'C10645T',
#   'C11020T',
#   'C11606T',
#   'C12357T',
#   'C12781T',
#   'C12915T',
#   'C13195T',
#   'C14120T',
#   'C14408T,C21618T,T22200G,A22688G,T27384C',
#   'C14408T,C21618T,T22200G,T27384C',
#   'C14408T,T22200G',
#   'C14408T,T22200G,A22688G,T27384C',
#   'C14408T,T27384C',
#   'C14805T',
#   'C15024T',
#   'C15237T',
#   'C15738T',
#   'C15763T',
#   'C16260T',
#   'C1627T',
#   'C16375T',
#   'C17463T',
#   'C17502T',
#   'C18086T',
#   'C18457T',
#   'C18501T',
#   'C1884T',
#   'C19220T',
#   'C19264T',
#   'C20405T',
#   'C2061T',
#   'C21058T',
#   'C21234T',
#   'C2147T',
#   'C21595T',
#   'C21638T',
#   'C21855T',
#   'C22783T',
#   'C22792T',
#   'C22879T',
#   'C22945T',
#   'C23013A',
#   'C23075T',
#   'C23277T',
#   'C23802T',
#   'C2470T',
#   'C25047T',
#   'C25460T',
#   'C26058T',
#   'C26256T',
#   'C26455T,C29585T',
#   'C26522T',
#   'C26534T',
#   'C26681T',
#   'C26996T',
#   'C27005T',
#   'C2701T,C21234T,C26801T',
#   'C27213T',
#   'C27453T',
#   'C27513T',
#   'C27549A',
#   'C27641T',
#   'C27732T',
#   'C2773T',
#   'C27741T',
#   'C28332A',
#   'C28432T',
#   'C28695T',
#   'C28896T',
#   'C2902T',
#   'C29272T',
#   'C29353T',
#   'C29632T',
#   'C29642T',
#   'C29708T',
#   'C29750T',
#   'C3096T',
#   'C4331T',
#   'C4668T',
#   'C5055T',
#   'C5183T',
#   'C5812T',
#   'C6145T',
#   'C6196T',
#   'C6388T,C23315T,C26885T',
#   'C6402T',
#   'C6543T',
#   'C6781T',
#   'C683T',
#   'C7029T',
#   'C7299T',
#   'C8139T',
#   'C8394T,C15720T',
#   'C875T,C24174T',
#   'C8818T',
#   'C8937T',
#   'C8950T,T16224C',
#   'C900T',
#   'C9246T',
#   'C9319T',
#   'C9344T',
#   'C936T',
#   'C9430T',
#   'C9866T,T14408C,C26060T,C26858T,G27382C,A27383T',
#   'C9979T',
#   'G12070T',
#   'G12797T',
#   'G17122T',
#   'G17686T',
#   'G18891T',
#   'G19999T',
#   'G20134T',
#   'G20352A',
#   'G210T',
#   'G21305A',
#   'G23048A',
#   'G23055A',
#   'G23599T,G29736T',
#   'G23611T',
#   'G25064T',
#   'G25135T',
#   'G25494A',
#   'G25785T',
#   'G25819A',
#   'G26065T',
#   'G26530A',
#   'G26577C',
#   'G26951T',
#   'G27157A',
#   'G27281T',
#   'G28209T',
#   'G2832A',
#   'G28374A',
#   'G28878C',
#   'G28925T',
#   'G315T,A28967G',
#   'G3562A',
#   'G376A,C23816T',
#   'G5012T,G23236T',
#   'G5515T',
#   'G5584A',
#   'G7252A',
#   'G7675T',
#   'G9053T',
#   'T11514C',
#   'T14508C',
#   'T1501C',
#   'T15096C',
#   'T17574A',
#   'T18438C',
#   'T19704C',
#   'T21615C',
#   'T21762C',
#   'T21925C,A24432G',
#   'T2201A',
#   'T22078C',
#   'T22674C',
#   'T22930C',
#   'T22939C',
#   'T23063A',
#   'T24448C',
#   'T2698C',
#   'T27152C',
#   'T27384C',
#   'T2992C',
#   'T400C',
#   'T4579A',
#   'T4756C',
#   'T5860C,C11931T',
#   'T6262C',
#   'T6334C',
#   'T8603C',
#   'T9640C'},
#  24: {'A10657G',
#   'A10972G',
#   'A11506G',
#   'A12634G',
#   'A1278G,C18929T',
#   'A13715G,C18555T',
#   'A14172G',
#   'A14553G',
#   'A15111G',
#   'A1547G',
#   'A18468G',
#   'A20055G',
#   'A20418G',
#   'A21137G',
#   'A2207C',
#   'A22688G',
#   'A22992G',
#   'A23083G',
#   'A23202C',
#   'A2550G',
#   'A26945G',
#   'A27894G',
#   'A28295G',
#   'A28816G',
#   'A3061G',
#   'A3601C,C9073T,A11342T',
#   'A3917G',
#   'A3936T',
#   'A3940G',
#   'A5484G,G17972T',
#   'A5875C,C11455T',
#   'A5891G',
#   'A652G',
#   'A652G,G26416A',
#   'A6709G',
#   'A7209G,C15277T',
#   'A8302G',
#   'A9052G',
#   'A9424G',
#   'C10507T',
#   'C10645T',
#   'C11152T',
#   'C11418T',
#   'C11653T',
#   'C11824T',
#   'C12025T',
#   'C12213T',
#   'C12809T',
#   'C1281T',
#   'C13072T',
#   'C13424T',
#   'C1380T',
#   'C13860T',
#   'C14184T',
#   'C14408T,C21618T,T22200G,A22688G,T27384C',
#   'C14599T',
#   'C14676T',
#   'C1473T',
#   'C147T',
#   'C14805T',
#   'C15141T',
#   'C15714T',
#   'C15960T',
#   'C15963T,G29620C',
#   'C16756T,T16939C',
#   'C1684T',
#   'C17127A,G20477T',
#   'C17304T',
#   'C17402T',
#   'C17634T',
#   'C176T,C20283T',
#   'C17999T',
#   'C18032T',
#   'C18060T',
#   'C18171T',
#   'C18348T',
#   'C18377T',
#   'C18647T',
#   'C18693T,G25217T',
#   'C19245T',
#   'C19390T',
#   'C19951A,C21846T',
#   'C20016T',
#   'C20104T',
#   'C20178T',
#   'C20703T',
#   'C21077T',
#   'C21304A',
#   'C21588T',
#   'C21595T',
#   'C21618T',
#   'C21618T,T22200G',
#   'C21635T',
#   'C21707T',
#   'C21767T',
#   'C22227T',
#   'C22673T',
#   'C22679T',
#   'C23013A',
#   'C23029T',
#   'C23625T',
#   'C23634T',
#   'C23673T',
#   'C24023T',
#   'C24106T',
#   'C2470T',
#   'C2485T',
#   'C25452T,T25478C',
#   'C25614T',
#   'C25665T',
#   'C25672T',
#   'C25693A',
#   'C26022T',
#   'C26058T',
#   'C26208T',
#   'C2623T',
#   'C26522T',
#   'C26622T',
#   'C26873T',
#   'C26985T',
#   'C27002T',
#   'C27230T',
#   'C27294T',
#   'C27297T',
#   'C27513T',
#   'C27577T',
#   'C27635T',
#   'C27874T',
#   'C27889T',
#   'C2790T',
#   'C27945A',
#   'C28087T',
#   'C2847T',
#   'C28498T',
#   'C28531T',
#   'C2862T',
#   'C28677T',
#   'C28849T',
#   'C28873T',
#   'C28915T',
#   'C2902T',
#   'C29065T',
#   'C29200T',
#   'C29586T',
#   'C29627T',
#   'C29632T',
#   'C29733T',
#   'C29738T',
#   'C29743T',
#   'C3241T',
#   'C335T',
#   'C3411T',
#   'C3426T,G9652T',
#   'C355A,C1457T,A23146G',
#   'C3587T',
#   'C3787T',
#   'C3817T',
#   'C4012T',
#   'C4099T,C13862T',
#   'C4158T',
#   'C4475T',
#   'C4543T',
#   'C4776T',
#   'C4891T',
#   'C5175T',
#   'C5203T',
#   'C5835T,C27384T',
#   'C5850T,A19365G',
#   'C5944T',
#   'C6258T',
#   'C6336T',
#   'C6354T',
#   'C6568T',
#   'C6633T,A18706G,C22458T',
#   'C6638T',
#   'C6701T',
#   'C6781T',
#   'C683T',
#   'C6855T',
#   'C7299T',
#   'C7401T',
#   'C7728T,A9848G',
#   'C7735T',
#   'C7860T',
#   'C835T',
#   'C8917T',
#   'C8986T',
#   'C9344T',
#   'C9541T',
#   'C9693T',
#   'C9803T,A22910G',
#   'C9866T',
#   'C9866T,C26858T',
#   'G10997A',
#   'G11417T',
#   'G12191T,G15602T',
#   'G12797T',
#   'G1466A',
#   'G15372T',
#   'G15672C',
#   'G18028T',
#   'G185A',
#   'G18651T',
#   'G1957A',
#   'G19666T,G20663A',
#   'G20275T',
#   'G20433T',
#   'G20578T',
#   'G20679A',
#   'G2086T',
#   'G2144A',
#   'G21770A',
#   'G21786T',
#   'G22332A',
#   'G22882T',
#   'G22882T,A22898G,G26530A',
#   'G23040A',
#   'G23055A',
#   'G23599T',
#   'G24098T',
#   'G2441A',
#   'G246A,T19641A',
#   'G24743T',
#   'G25401T',
#   'G25593T',
#   'G25660T',
#   'G25855C',
#   'G26596T',
#   'G27637T',
#   'G27915A',
#   'G28041T',
#   'G28079T',
#   'G28747T',
#   'G2879A,C11941T,G22468T',
#   'G28936T',
#   'G28942A',
#   'G29345A',
#   'G29706T',
#   'G29764A',
#   'G3403T',
#   'G3562A',
#   'G389A',
#   'G4444A',
#   'G4960T',
#   'G5012T',
#   'G5515T',
#   'G7042T',
#   'G7393T',
#   'G7761A',
#   'G960A',
#   'T1054C',
#   'T10885C',
#   'T11187C',
#   'T11514C',
#   'T11773A',
#   'T12427C',
#   'T12628C',
#   'T12865C',
#   'T13114C',
#   'T13417C',
#   'T15240C,T21846C',
#   'T15784C',
#   'T15888C',
#   'T16242C',
#   'T17103C',
#   'T17865C',
#   'T18876C',
#   'T21846C',
#   'T22813G',
#   'T22917G',
#   'T23063A',
#   'T23986C',
#   'T24331A',
#   'T24664C',
#   'T24995C,C25566T',
#   'T25485A',
#   'T25704C',
#   'T27384C',
#   'T27384C,T29753C',
#   'T27409C',
#   'T27568C',
#   'T27591C',
#   'T27634C',
#   'T28251C',
#   'T28251G',
#   'T3325G',
#   'T4714C',
#   'T4837C',
#   'T6148C,C13515T,C16173T,G17944T,G19900A',
#   'T9016C',
#   'T967C,G970A,C6840T'},
#  25: {'A10195G',
#   'A10904G',
#   'A11047G,T20273C',
#   'A11588G',
#   'A12611G',
#   'A12634G',
#   'A13204G,T22552C',
#   'A13949G',
#   'A18585C',
#   'A18846G',
#   'A19126G',
#   'A19440G,C20946T',
#   'A19464G,A28169G',
#   'A19667G',
#   'A20318G,G20925T',
#   'A20667G',
#   'A21766C',
#   'A21768C',
#   'A22688G',
#   'A22898G',
#   'A22992G',
#   'A23604C',
#   'A24130C',
#   'A25998G',
#   'A2730G',
#   'A27753G',
#   'A28081C',
#   'A2810G,C10954T,G25769T',
#   'A28880G',
#   'A2895C',
#   'A4490G',
#   'A5536G',
#   'A6411G,G13749T',
#   'A7863G',
#   'A8965G',
#   'A9424G',
#   'C10156T',
#   'C10198T',
#   'C10702T',
#   'C1076T',
#   'C10789T',
#   'C10790T',
#   'C11003A',
#   'C11200T,C15857T',
#   'C11418T',
#   'C11620T',
#   'C11941T',
#   'C12049T',
#   'C12115T',
#   'C12641T',
#   'C1267T,T2029C,G8322A,C10036T,C19263T,C19554T,G25249T,G26538A',
#   'C13011T',
#   'C13011T,T22942C,T27384C',
#   'C13140T',
#   'C13176T',
#   'C13297T',
#   'C1420T',
#   'C14599T',
#   'C15026T',
#   'C15101T,T29576C',
#   'C1513T',
#   'C15240T',
#   'C15277T',
#   'C15720T',
#   'C15738T',
#   'C1594T',
#   'C15960T',
#   'C16289T',
#   'C16616T',
#   'C17119T',
#   'C17285T',
#   'C17285T,G18756T,G28242T',
#   'C173T',
#   'C17747T',
#   'C17762T',
#   'C17850T,G27709T,C28603T',
#   'C18981T',
#   'C19032T',
#   'C19185T',
#   'C19186T',
#   'C19186T,A22005C',
#   'C19524T',
#   'C19970T,C27575T',
#   'C20148T',
#   'C203T',
#   'C20544T',
#   'C2061T,C7764T,G25437C,C25782T,G26951T',
#   'C207T',
#   'C2110T,C10507T,G10618A',
#   'C21812A',
#   'C22224T',
#   'C22792T',
#   'C2295T,C6336T,C21639T,C27590T',
#   'C22987T',
#   'C23029T',
#   'C2306T',
#   'C23077T',
#   'C23114T',
#   'C233T,G10805A,G29402T',
#   'C23635T',
#   'C23707T',
#   'C24026T',
#   'C24378T',
#   'C24502A',
#   'C24621T',
#   'C2469T',
#   'C2508T,C2675T',
#   'C25096T',
#   'C25350T',
#   'C25416T',
#   'C25482T',
#   'C25626T',
#   'C25658T',
#   'C25701T',
#   'C25889T',
#   'C26681T',
#   'C2710T,G7675T,C8326T,C18582T',
#   'C27247T',
#   'C27434T',
#   'C27577T',
#   'C27684T',
#   'C27741T',
#   'C2788T',
#   'C2790T',
#   'C27942T',
#   'C28087T',
#   'C28214T',
#   'C28236A',
#   'C28472T',
#   'C28603T',
#   'C28695T',
#   'C29750T',
#   'C2983T,A3528C,C6539T,G8287T,C10252T,A12103T,C13708A,C25276T,C28087T',
#   'C3261T',
#   'C3634T',
#   'C3787T',
#   'C3817T',
#   'C3903T',
#   'C4276T',
#   'C4421T',
#   'C4551T,C27847T',
#   'C4832T',
#   'C5007T',
#   'C5100T,A21993C',
#   'C5144T',
#   'C5365T',
#   'C5672T',
#   'C5886T',
#   'C593T',
#   'C6070T,A15219G,C22930T',
#   'C6402T',
#   'C6633T',
#   'C6762T',
#   'C683T',
#   'C7164T',
#   'C7401T',
#   'C745T',
#   'C7521T',
#   'C758T',
#   'C7749T',
#   'C774T,C17985T',
#   'C7823T,T18537A',
#   'C7926T',
#   'C8092T',
#   'C8123T',
#   'C823T',
#   'C8320T,C10440T',
#   'C8639T',
#   'C8829A',
#   'C8982T',
#   'C9166T',
#   'C9286T,C13724T',
#   'C9344T',
#   'C9611T',
#   'C9857T',
#   'C9967T',
#   'C9996T',
#   'G12131A',
#   'G1508A,G1944A,C4900T',
#   'G15627T',
#   'G15658A',
#   'G1719A',
#   'G18756T',
#   'G19879A',
#   'G20756T',
#   'G2173T,G4180T',
#   'G21770A',
#   'G22022C,G23012A',
#   'G22882T',
#   'G22899A',
#   'G23055A',
#   'G23522A',
#   'G24506T',
#   'G24882A',
#   'G25249A',
#   'G2527T',
#   'G25534T',
#   'G25855T',
#   'G25879T',
#   'G26158T',
#   'G26787A',
#   'G27382C',
#   'G27601T',
#   'G27754T',
#   'G2782T',
#   'G27841T',
#   'G27870T',
#   'G28079T',
#   'G28423T',
#   'G28460C',
#   'G28690T',
#   'G28871T',
#   'G29300C',
#   'G29717T',
#   'G29759T',
#   'G3004T',
#   'G3052A,C6896T,A9243C,C18981T,T28095A',
#   'G3242A',
#   'G3250T,T18499C',
#   'G3302A',
#   'G4136T',
#   'G4148T',
#   'G4280A',
#   'G488A',
#   'G7756T',
#   'G9203A',
#   'T10163C',
#   'T14394C',
#   'T14408C,C26060T,G27382C,A27383T',
#   'T14643C',
#   'T16446C',
#   'T17169C',
#   'T17181C',
#   'T17574A',
#   'T18018C',
#   'T18465C,C19366T',
#   'T18685A',
#   'T19015C',
#   'T1965C',
#   'T2027G',
#   'T20534C',
#   'T21500C,C29774T',
#   'T21846C',
#   'T22612C',
#   'T2264C',
#   'T22674C',
#   'T22686C',
#   'T22777C,G29747A',
#   'T23063A',
#   'T23131C',
#   'T23323C',
#   'T23371C',
#   'T23560C',
#   'T25180C,C29304T',
#   'T25950C',
#   'T26624G',
#   'T27384C',
#   'T27639C,A29394G',
#   'T27722C',
#   'T27807C',
#   'T28095A',
#   'T28136G',
#   'T28245G',
#   'T28311C',
#   'T28705C',
#   'T29632C',
#   'T5290C',
#   'T5338C',
#   'T5386G,T21762C',
#   'T6402C',
#   'T7984C',
#   'T8737C',
#   'T902C',
#   'T9088C',
#   'T9127C',
#   'T9866C',
#   'T9891C'},
#  26: {'A10323G',
#   'A11332G',
#   'A11749G',
#   'A1381G,T3067C,C8293A',
#   'A14823G',
#   'A17056G',
#   'A17337G',
#   'A17615G,C28045T,C29614T',
#   'A178G',
#   'A20442G',
#   'A21768C,A21993T',
#   'A22578G',
#   'A23923T',
#   'A24920T,T27384C,C29200T',
#   'A25247G',
#   'A25574G',
#   'A26045G',
#   'A27383T',
#   'A2832G',
#   'A29549G',
#   'A29725G',
#   'A29725T',
#   'A3009G',
#   'A6108G,T27977C',
#   'A6659G',
#   'A7918G',
#   'A9424G',
#   'A969G',
#   'C10340T',
#   'C10741T',
#   'C11173T',
#   'C11750T',
#   'C11902T',
#   'C11950T',
#   'C12025T',
#   'C12400T',
#   'C12741T,T27511C',
#   'C12786T',
#   'C1288T',
#   'C13860T,A17205G',
#   'C1437T',
#   'C14805T',
#   'C14898T',
#   'C15120T',
#   'C1513T',
#   'C15952T',
#   'C16111T,A28113G',
#   'C16443T',
#   'C1670A',
#   'C17004T',
#   'C17676T',
#   'C17703T,C25791T,C28732T',
#   'C18131T',
#   'C18189T',
#   'C18303T',
#   'C18576T',
#   'C1909T',
#   'C19862T',
#   'C19955T',
#   'C2037T',
#   'C203A',
#   'C20825T',
#   'C2106T',
#   'C21597T',
#   'C21742T',
#   'C21762T',
#   'C21767T',
#   'C21859T',
#   'C22120T',
#   'C22224T,T28017A',
#   'C222T',
#   'C22326T',
#   'C22377T',
#   'C22679T',
#   'C22792T',
#   'C22987T',
#   'C23029T,C25452T',
#   'C23802T',
#   'C23934T',
#   'C2395T',
#   'C2416T',
#   'C24378T',
#   'C2453T,T18224C',
#   'C24621T',
#   'C24914G',
#   'C24990T',
#   'C2536T',
#   'C25416T',
#   'C25546T',
#   'C25549T',
#   'C25831T',
#   'C25844T',
#   'C25916T',
#   'C25941T',
#   'C26013T',
#   'C26078T',
#   'C26110T',
#   'C2623T',
#   'C26542A,C29670T',
#   'C26645T',
#   'C27384T',
#   'C27476T',
#   'C27532T',
#   'C27643T',
#   'C27765T',
#   'C2790T',
#   'C27970T',
#   'C28313T',
#   'C28603T',
#   'C28606T',
#   'C2892T',
#   'C2902T',
#   'C29144T',
#   'C29272T',
#   'C29466T',
#   'C29586T',
#   'C29722T',
#   'C346T',
#   'C3510T',
#   'C3874A',
#   'C3876T',
#   'C4039T',
#   'C4449T,C6114T',
#   'C4455T',
#   'C4456T',
#   'C4752A,T12496C',
#   'C4788A',
#   'C4891T',
#   'C4900T',
#   'C5051T',
#   'C5144T',
#   'C5239T',
#   'C5497T,C5575T',
#   'C5646T',
#   'C583T,C26882T',
#   'C5869T',
#   'C6196T',
#   'C6627T',
#   'C6636T',
#   'C6638T',
#   'C6968T',
#   'C6997A',
#   'C7113T',
#   'C7681T,C26912T',
#   'C7764T',
#   'C7869T,G9575A,G22632A,C25916T',
#   'C794T,A1739C',
#   'C8139T',
#   'C8655T',
#   'C8986T',
#   'C9344T',
#   'C9430T',
#   'G10396T,A28877T,G28878C',
#   'G10540T',
#   'G1148T',
#   'G11552A',
#   'G12067T',
#   'G12071A',
#   'G14712T',
#   'G14874T,C19524T',
#   'G1487A',
#   'G17079A',
#   'G17338T',
#   'G185T',
#   'G19207A',
#   'G19518T',
#   'G21853T',
#   'G22103C',
#   'G22541A',
#   'G22882T',
#   'G23055A',
#   'G24000T',
#   'G2447T',
#   'G25305A',
#   'G25348A',
#   'G25481A',
#   'G25500T',
#   'G25784C',
#   'G28075T',
#   'G28378C',
#   'G28423C',
#   'G29044A',
#   'G29239A',
#   'G3320T',
#   'G332A,C643T',
#   'G3431T',
#   'G3692T',
#   'G376T',
#   'G4504T',
#   'G670T',
#   'G695T',
#   'G7143A,C22033A',
#   'G8075A',
#   'T10012A',
#   'T11475C,A25003G,C27673A',
#   'T13019C,T22227C',
#   'T13090C',
#   'T13672G',
#   'T1390C,C6968T',
#   'T15437C',
#   'T1570C',
#   'T177C',
#   'T19220C',
#   'T20697C',
#   'T20976C',
#   'T21595C',
#   'T21656C,C24797T',
#   'T22114C',
#   'T22686C',
#   'T22813G',
#   'T22879C',
#   'T23323C',
#   'T23371C',
#   'T23716C',
#   'T25689C',
#   'T26546C',
#   'T26681C',
#   'T27384C',
#   'T27504C',
#   'T27511A',
#   'T27953C',
#   'T28095A',
#   'T28916G',
#   'T29104C',
#   'T29524C',
#   'T29685G',
#   'T4057C',
#   'T4579A',
#   'T6175C',
#   'T9151C',
#   'T9891C'},
#  27: {'A11201G',
#   'A11201G,A27345T',
#   'A13063G',
#   'A13288C',
#   'A1381G',
#   'A18846G,T26448C',
#   'A1955G',
#   'A23767G',
#   'A23938G',
#   'A25442C',
#   'A25505T',
#   'A25927G',
#   'A28777G',
#   'A28881G,A28882G,C28883G',
#   'A3084G',
#   'A489G,C10332T',
#   'A8882G',
#   'A9424G',
#   'C10296T',
#   'C10376T',
#   'C10582T,C14220T,G27382C,A27383T,T27384C,C27641T',
#   'C10747T',
#   'C11001T',
#   'C11109T,C19032T',
#   'C1150T',
#   'C11620T,G12067T,G22988A',
#   'C11750T',
#   'C1191T,C1267T',
#   'C12049T',
#   'C12084T',
#   'C12651T',
#   'C13119T',
#   'C13274T',
#   'C13458T',
#   'C13862T',
#   'C13945T',
#   'C13994T',
#   'C14189T',
#   'C14408T,C21618T,T22200G,A22688G',
#   'C15096T',
#   'C15108T',
#   'C15240T,T22813G,C24503T',
#   'C15720T',
#   'C15738T',
#   'C16393T',
#   'C16394T',
#   'C16733T',
#   'C17010T',
#   'C17502T',
#   'C17734T',
#   'C18189T',
#   'C18329T',
#   'C18395T',
#   'C18570T',
#   'C18591G',
#   'C19164T',
#   'C1919T',
#   'C19374T',
#   'C19602T',
#   'C19662T',
#   'C19662T,T24472C',
#   'C1968T',
#   'C19862T',
#   'C203T',
#   'C20483T',
#   'C20740A,A28055G',
#   'C21005T',
#   'C21008T',
#   'C21304T,C29525G',
#   'C21365T',
#   'C21588T',
#   'C21846T',
#   'C22792T',
#   'C23013A',
#   'C23191T',
#   'C2334T',
#   'C23506T',
#   'C23625T',
#   'C23683T',
#   'C23757T',
#   'C23895T,T27977C',
#   'C24969T',
#   'C25047T',
#   'C2504T,C13424T',
#   'C25416T',
#   'C25513T',
#   'C26681T',
#   'C26768T',
#   'C26801T',
#   'C26858T',
#   'C27532T',
#   'C27881T',
#   'C2790T',
#   'C28054T',
#   'C28312T',
#   'C28606T',
#   'C2902T',
#   'C29250T',
#   'C29272T',
#   'C29370T',
#   'C29642T',
#   'C2973T',
#   'C29743T',
#   'C311T',
#   'C337T',
#   'C4206T',
#   'C4582T',
#   'C4633T',
#   'C4703T,C15933T',
#   'C5184T',
#   'C5694T',
#   'C5884T',
#   'C6196T',
#   'C6606T,G28028T',
#   'C6706T',
#   'C6983T',
#   'C7162T',
#   'C7279T',
#   'C7420T',
#   'C7728T',
#   'C7732T',
#   'C7765T',
#   'C8016T',
#   'C8318A',
#   'C8739T',
#   'C8802T',
#   'C9286T',
#   'C9430T',
#   'C9448T,C25275T',
#   'C9510T,C29754T',
#   'C9565T',
#   'C9778T',
#   'G10106A',
#   'G10678A',
#   'G11287T,G11291A,G21770A,A28363T,A28370G',
#   'G12070A',
#   'G12080A',
#   'G12163T',
#   'G1280A',
#   'G12911A',
#   'G13659A',
#   'G13713A',
#   'G14767T',
#   'G15672T',
#   'G18028T',
#   'G1820A',
#   'G21255C',
#   'G24893C',
#   'G25091A',
#   'G25769T',
#   'G25855T',
#   'G26577C',
#   'G28242C',
#   'G28287A',
#   'G28655A',
#   'G29468T',
#   'G29734A',
#   'G3047T',
#   'G3307A,T7714C',
#   'G488A,G15313A',
#   'G6694T',
#   'G8572T,C10186T',
#   'G9473A',
#   'T10029C',
#   'T10692C',
#   'T1099C',
#   'T11118C',
#   'T11122A',
#   'T13019C,T22227C',
#   'T13997C',
#   'T15420C',
#   'T15437C',
#   'T1570C',
#   'T17863C',
#   'T1937C',
#   'T19896C',
#   'T20016C',
#   'T20653C',
#   'T21595C',
#   'T21992G',
#   'T22686C',
#   'T23239C',
#   'T25400C,G26530A',
#   'T27349C',
#   'T27504C',
#   'T27682C',
#   'T27696G',
#   'T2790C',
#   'T27986A',
#   'T28095A',
#   'T28235G',
#   'T29623C',
#   'T335C,G557A',
#   'T3766C',
#   'T5144C',
#   'T7124C',
#   'T8473C'},
#  28: {'A10042G',
#   'A11755G',
#   'A12555G',
#   'A1307G',
#   'A15162G,C17439T',
#   'A15451G,T16466C',
#   'A18550G',
#   'A18585C,A20418G',
#   'A19974G',
#   'A2006G',
#   'A21643G',
#   'A22002G,C27849T',
#   'A22633G',
#   'A22812G',
#   'A23048G',
#   'A23594G',
#   'A27038G',
#   'A29407G',
#   'A29700G',
#   'A8845G',
#   'C10036T,G29212A',
#   'C100T',
#   'C10198T',
#   'C10519T',
#   'C10834T',
#   'C1142A',
#   'C11620T',
#   'C11704T',
#   'C11750T',
#   'C1191T',
#   'C1191T,C1267T',
#   'C12076T',
#   'C12469T',
#   'C12970T',
#   'C13551T',
#   'C13761T',
#   'C14322T',
#   'C15660A',
#   'C15720T',
#   'C15848T,G26526T',
#   'C15952T',
#   'C15960T,G25305T',
#   'C16111T',
#   'C16178T',
#   'C16611T',
#   'C1710T',
#   'C17676T',
#   'C17747T',
#   'C17766T',
#   'C19156T',
#   'C19512T',
#   'C19572T,G25947C',
#   'C19586T',
#   'C20429T',
#   'C20930T',
#   'C21161T',
#   'C21597T',
#   'C21846T',
#   'C21859T',
#   'C22088T',
#   'C22624A',
#   'C22792T',
#   'C24026T',
#   'C2453T',
#   'C24734T',
#   'C24904T',
#   'C24961A',
#   'C25416T',
#   'C25614T',
#   'C25626T',
#   'C25810T',
#   'C26681T',
#   'C26895T',
#   'C27654T',
#   'C2790T',
#   'C28312T',
#   'C28603T',
#   'C28724T',
#   'C28868T',
#   'C29409T',
#   'C29721T',
#   'C29738T',
#   'C29769T',
#   'C3653T',
#   'C3666T,G26727T',
#   'C3874T',
#   'C4206T',
#   'C4893T',
#   'C4921T',
#   'C5147T',
#   'C5392T',
#   'C5746T',
#   'C601T',
#   'C6040T,C16716G',
#   'C6196T',
#   'C6285T',
#   'C6286T',
#   'C6402T',
#   'C6433T',
#   'C6568T',
#   'C6990T',
#   'C7108T',
#   'C7600T',
#   'C7926T',
#   'C823T',
#   'C8266T',
#   'C8318A',
#   'C8772T',
#   'C8991T',
#   'C9118T,C29750T',
#   'C925T',
#   'C9344T',
#   'C9565T',
#   'C9891T',
#   'G11540A',
#   'G12067T',
#   'G1299A',
#   'G13161A,T13162C',
#   'G160A',
#   'G18255T',
#   'G18325A',
#   'G20055A',
#   'G20131A',
#   'G210T',
#   'G21770A',
#   'G22111A',
#   'G22205C',
#   'G22882T',
#   'G23055A',
#   'G23055A,T23063A',
#   'G23126C',
#   'G236A,T14361C,A24970G,T27995C',
#   'G23856T',
#   'G23984T',
#   'G25696A',
#   'G25906T',
#   'G2591T',
#   'G26158T',
#   'G28251T,C28254A',
#   'G28880A',
#   'G29543T',
#   'G29593T',
#   'G3259T',
#   'G3434A,G11527T',
#   'G3446A',
#   'G3482A',
#   'G388A',
#   'G4181T,A11201G,C16466T,G18163A,C21618G,A22578G,C22679T,T22686C,T22917G,C25469T,T25584C,T26270C,C27259A,T27807C',
#   'G4205A',
#   'G428A',
#   'G6717A',
#   'G8258T',
#   'G9245A,C22264T',
#   'G9856T',
#   'T10573C',
#   'T11218C,C19200T',
#   'T11524C,A11537G',
#   'T12811C',
#   'T19220C',
#   'T22813G,G22882T,A22898G',
#   'T234C',
#   'T24364C',
#   'T2470C',
#   'T26110C',
#   'T26158G',
#   'T27297C',
#   'T27765C',
#   'T28902C',
#   'T28916G',
#   'T4630C,T27381C,G27382T,A27383G',
#   'T5944C',
#   'T6336C',
#   'T7424C',
#   'T7438C,C28232T',
#   'T7767C,C27303T',
#   'T8654G,C25276T,C26936T',
#   'T9412C'},
#  29: {'A10323G',
#   'A11332G',
#   'A13938G',
#   'A14338G,C21036T,A22053G,C25667T,C25703T,C26801T,G28248A,T28251G,G29648T',
#   'A14412G',
#   'A15451G,T16466C',
#   'A17496G',
#   'A17508C',
#   'A18360G',
#   'A20658G',
#   'A22599G',
#   'A23048G',
#   'A231G,G3728T',
#   'A23767G',
#   'A23941T',
#   'A28467G',
#   'A6121G,C29144T',
#   'A6930G,C27509T',
#   'A9263G,A29700G',
#   'A9424G',
#   'C10078T',
#   'C10156T',
#   'C10369T',
#   'C11747T',
#   'C1191T',
#   'C12525T',
#   'C13011T',
#   'C14793T',
#   'C14898T',
#   'C15240T',
#   'C15546T',
#   'C15613T,A18227G,C26681T,C27641T',
#   'C15738T',
#   'C16726T',
#   'C16859T',
#   'C17125T',
#   'C17550T',
#   'C18364T,G27556T,C29203T',
#   'C18647T',
#   'C186T,A7479G',
#   'C19156T',
#   'C1915T',
#   'C19170T',
#   'C19273T',
#   'C19961T',
#   'C19983T',
#   'C20235A',
#   'C21207T',
#   'C2143T',
#   'C22224T',
#   'C22227T',
#   'C22686T',
#   'C22792T',
#   'C23075T',
#   'C23248T',
#   'C24370T,G26526T',
#   'C25355T',
#   'C26767T',
#   'C27059T',
#   'C27131T',
#   'C27532A',
#   'C27549T',
#   'C27638T',
#   'C280T',
#   'C28422T',
#   'C28708T',
#   'C28961T',
#   'C2925T',
#   'C2939T',
#   'C29537T',
#   'C29541T',
#   'C29546A',
#   'C313T',
#   'C344T',
#   'C3634T',
#   'C4068T',
#   'C4234T',
#   'C4438T',
#   'C4540T',
#   'C4788A',
#   'C4893T',
#   'C5482T',
#   'C6070T',
#   'C6380T',
#   'C6573T',
#   'C6633T',
#   'C664T,G28739T',
#   'C6726T,G20269A',
#   'C7056A',
#   'C7267T',
#   'C7735T',
#   'C7768T',
#   'C8208T',
#   'C8626T,G21004T,C27286T',
#   'C8639T',
#   'C8950T',
#   'C9857T',
#   'G12163T',
#   'G14055T',
#   'G17064T,C23896T',
#   'G17679T',
#   'G19388A',
#   'G19999T',
#   'G22014T,G27415A',
#   'G22317A',
#   'G22580C',
#   'G23285T',
#   'G24199A',
#   'G25218T',
#   'G25455T',
#   'G25534T',
#   'G25775T',
#   'G26031A',
#   'G27841A',
#   'G2832A',
#   'G28423T',
#   'G29348T',
#   'G29706T',
#   'G3239T',
#   'G4444T',
#   'G6650A',
#   'G7344A',
#   'G8858A',
#   'G9190A,A21356C',
#   'T10033C',
#   'T10198C',
#   'T11418C',
#   'T11524C,A11537G',
#   'T1177C',
#   'T12835C',
#   'T13188C',
#   'T16695C',
#   'T1771C,A11342G,C26125A',
#   'T212A',
#   'T21995C',
#   'T22197C',
#   'T22792C',
#   'T22795C',
#   'T22813G,G22882T,A22898G,A23854C,G26530A,G26577C,A26709G',
#   'T24793C',
#   'T26969C',
#   'T27383A,C27384T',
#   'T28095A',
#   'T28118C',
#   'T2902C',
#   'T29624C',
#   'T3004G',
#   'T312C,C29284T',
#   'T3160A',
#   'T4206C',
#   'T4579A',
#   'T5386G',
#   'T6661C',
#   'T692C',
#   'T7582C',
#   'T8008A',
#   'T946C',
#   'T9508C'},
#  30: {'A10874G,T20407C',
#   'A11595G',
#   'A13488G',
#   'A13748G,G21255C,C21721T',
#   'A17496G',
#   'A1804G,C17304T',
#   'A18503G',
#   'A23048G',
#   'A23055G',
#   'A23854C',
#   'A27986T',
#   'A28095T',
#   'A3722G',
#   'A6331G',
#   'A7519C',
#   'A7972G',
#   'A802G',
#   'A8380G',
#   'C10138T',
#   'C10456T',
#   'C11224T',
#   'C12008T',
#   'C12400T',
#   'C12763T',
#   'C13019T',
#   'C15324T',
#   'C17550T,C25521T',
#   'C18744T',
#   'C19688T',
#   'C19896T',
#   'C2003T',
#   'C2061T',
#   'C20677T,C21658T',
#   'C206T',
#   'C20762T,C27638T,T28820A',
#   'C21205T',
#   'C21365T',
#   'C21721T',
#   'C222T',
#   'C23239T',
#   'C23683T',
#   'C25516T',
#   'C25904T',
#   'C26801T',
#   'C2790T',
#   'C28280G,T28281A,A28282T',
#   'C2902T,A3492G',
#   'C29509T',
#   'C29721T',
#   'C29762T',
#   'C3505T',
#   'C3817T',
#   'C4391A',
#   'C4582T',
#   'C4668T,C26527T',
#   'C556T',
#   'C5693T',
#   'C583T',
#   'C6250T',
#   'C6388T',
#   'C643T',
#   'C6573T',
#   'C7945T',
#   'C8016T,C12012T,C19983T',
#   'C8109T',
#   'C8127T',
#   'C9451T',
#   'G11114A,C27641T',
#   'G11401T',
#   'G1261A',
#   'G17388A',
#   'G18910T',
#   'G20002T',
#   'G20397A',
#   'G21793T',
#   'G22882T',
#   'G23040A',
#   'G23593C',
#   'G23599T,A23604C',
#   'G23767A',
#   'G24219T',
#   'G25599T,T27576C',
#   'G25720T',
#   'G26211T,T27807C',
#   'G26713T',
#   'G26730A',
#   'G2782A',
#   'G29440A',
#   'G29648T',
#   'G29688T',
#   'G3782A',
#   'G91T,G4476A,A6521G',
#   'T10480C',
#   'T11296G',
#   'T11750C,T28095A',
#   'T12946C',
#   'T17040C',
#   'T17250A,G20126A',
#   'T17502C',
#   'T18189C',
#   'T19374C',
#   'T22792C',
#   'T22813G',
#   'T25604C',
#   'T25899C',
#   'T27529C',
#   'T27752C',
#   'T2902C',
#   'T29173C',
#   'T311C',
#   'T3259G',
#   'T4206C',
#   'T4369C',
#   'T7822C',
#   'T7957C,C25413T',
#   'T847A',
#   'T9232C',
#   'T9678C,C11005A'},
#  31: {'A10195G,T17859C,T28048G,G28075T',
#   'A12334T',
#   'A18102G',
#   'A20262G,C27739T',
#   'A26702G',
#   'A28615C',
#   'A29567G',
#   'A6063G',
#   'C10078T',
#   'C15457T',
#   'C15720T',
#   'C1594T',
#   'C16293T',
#   'C16616T',
#   'C18555T',
#   'C186T,G2095A,C5175T,A5760G,G22899T,A27250G,T27752C,C28093T',
#   'C19206T,G21724T',
#   'C19944T',
#   'C222T,C18166T,G20356A,G29227T',
#   'C22792T',
#   'C24034T',
#   'C24096G',
#   'C24138T,C26625T',
#   'C2485T,A2866C,G16696T',
#   'C25380T',
#   'C25416T',
#   'C26010T',
#   'C26022T',
#   'C26885T',
#   'C28236T',
#   'C2942T',
#   'C29642T',
#   'C29708T',
#   'C4331T,C11750T,G29474T',
#   'C4672T',
#   'C5184T',
#   'C6196T',
#   'C6196T,G9953C,G18043A,G19947T,A22775G,T23525C',
#   'C6843A',
#   'C6843T',
#   'C7764T',
#   'G10870T,T27299C',
#   'G11291A',
#   'G14118A',
#   'G15007A,C19951T,T23677C,T28114C',
#   'G15732T',
#   'G16744A',
#   'G20578T',
#   'G23040A',
#   'G24348T',
#   'G2441A',
#   'G25186T,G29737T',
#   'G25599T',
#   'G26530A',
#   'G29260A',
#   'G5206T',
#   'G5515T',
#   'G9203A',
#   'G9224A,C11379T',
#   'T13438C',
#   'T1623C,C6541T,A9496G',
#   'T18189C',
#   'T1891C',
#   'T210G',
#   'T21973C',
#   'T22792C',
#   'T23371C',
#   'T23856G',
#   'T24079C',
#   'T28048G',
#   'T28422C',
#   'T4011C',
#   'T6489C',
#   'T7183C',
#   'T8656C',
#   'T8986C,C21762T,T23599G,G23604A',
#   'T9678C,C11005A'},
#  32: {'A15742G',
#   'A20396G',
#   'A22992G',
#   'A23767G',
#   'A28877T,G28878C',
#   'A3805T,G14364A,A29359G',
#   'C10714T',
#   'C1102T,C17676T,G24794T,C25433T',
#   'C1142A',
#   'C12676T',
#   'C14697T',
#   'C15240T',
#   'C15240T,G21375A,T22792C',
#   'C1555T,C2918T',
#   'C16726T,G18651T,G29593T',
#   'C17104T',
#   'C173T',
#   'C18175T',
#   'C20320T,C24745T',
#   'C20480T',
#   'C20483T,C25889T',
#   'C21658T',
#   'C21846T',
#   'C25614T',
#   'C26133T',
#   'C26370T',
#   'C28087T',
#   'C2847T,C24048T,C26571T',
#   'C28677T',
#   'C29272T',
#   'C4586T',
#   'C6194T',
#   'C6606T',
#   'C6627T',
#   'C683T',
#   'C6848T',
#   'C7735T',
#   'C7932T',
#   'G10642T,C12025T,G23012C,C26111T',
#   'G1148T,A26059G',
#   'G13459A',
#   'G14452A',
#   'G15463T',
#   'G1599A',
#   'G198A,C28453T',
#   'G21800T',
#   'G22599A',
#   'G24445T',
#   'G27613A',
#   'G28003T',
#   'G28712A',
#   'G5012T',
#   'G9203A',
#   'T22686C',
#   'T22792C',
#   'T22813G',
#   'T27504C,C27644T',
#   'T27638C,C27752T',
#   'T28916G',
#   'T7026C,G25819T',
#   'T7424C',
#   'T8359C',
#   'T8729C',
#   'T8986C,C20148T'},
#  33: {'A14070G',
#   'A1573C',
#   'A20396G',
#   'A21792C',
#   'A22995C',
#   'A257G',
#   'A28877T,G28878C',
#   'A6486G',
#   'C10340T',
#   'C11200T',
#   'C11752T',
#   'C13115T',
#   'C15240T',
#   'C18555T',
#   'C21178T,C25487T,C28846T',
#   'C21627T,G26031A',
#   'C21707T',
#   'C21846T',
#   'C22792T',
#   'C27596T',
#   'C27972T',
#   'C292T',
#   'C2983T',
#   'C5407T,T18423A,T24496C,C26822T',
#   'C5628T',
#   'C799T,A23920G',
#   'G14400A',
#   'G22225A',
#   'G22346T',
#   'G22882T',
#   'G24794T',
#   'G29427A',
#   'G3287A,C19524T',
#   'G3434A,G11527T',
#   'G3860T',
#   'G3965A',
#   'G922A',
#   'T14709C',
#   'T22861C',
#   'T25433C,T25469C',
#   'T26515C',
#   'T28095A',
#   'T4036C',
#   'T8176C,G18816T'},
#  34: {'A20319G',
#   'A21792C',
#   'C12743A',
#   'C12763T,C15026T,C18312T',
#   'C16985T',
#   'C18693T',
#   'C21846T',
#   'C22686T',
#   'C28310T',
#   'C2902T,G22578A',
#   'C6027A',
#   'C6539T',
#   'C6541T',
#   'C7119T,T19964G,C20594T,C24378T,G25690T',
#   'G12361T',
#   'G14030A',
#   'G198T',
#   'G29468T',
#   'G443A',
#   'T12025C',
#   'T18151C,C26124A',
#   'T22792C',
#   'T24796G',
#   'T27299C',
#   'T3631A,C27752T',
#   'T8566C,C10755T,G23438T,C25803T'},
#  35: {'A17585C',
#   'A21766C',
#   'A330G,G2235A,C5497T,C25162A',
#   'A4675G,C24023T',
#   'C16915T',
#   'C2137A',
#   'C2142T',
#   'C21846T',
#   'C25096T',
#   'C29632T',
#   'C29754T',
#   'C3787T,C14220T',
#   'C4084T,G22487C',
#   'C6027A',
#   'C7851T',
#   'G11113A',
#   'G19735T',
#   'G8353A',
#   'T19220C',
#   'T21762C,G26577C',
#   'T241C'},
#  36: {'C10989T',
#   'C11941T',
#   'C16915T',
#   'C21846T',
#   'C29774T',
#   'G1738T,C27297T',
#   'G17808A',
#   'G18078T,C29358T',
#   'G2516T',
#   'G25489T',
#   'T23075C',
#   'T6148C'},
#  37: {'A1321C,G1322T,G1323A',
#   'C17304T',
#   'C21766A',
#   'C21846T',
#   'C27131T',
#   'C29520T',
#   'C8802T,C29632T',
#   'C888T,A27423G,G28242A'},
#  38: {'C21846T', 'C25487T', 'G2305T,C8836T,C18246T'},
#  39: {'G8017T'},
#  40: {'C117T,C13051T,C25624T'},
#  41: {'A26579G,C29200T'}}
